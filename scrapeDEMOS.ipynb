# %% [markdown]
# ### **Install dependencies**

# %%
# !pip install -r "_functions/requirements.txt"

# %% [markdown]
# ### **Importing the functions from python files**

# %%
from _functions.get_matches_url import get_matches_url
from _functions.get_match_id import get_match_ids
from _functions.get_request import get_request
from _functions.download_files import download_files
from _functions.unrar import unrar
from _functions.extrair_dados import run_csda_on_demos
from _ETL.merge_files import merge_csv_files
import os
from _functions.chromelib import pd

# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Disable line wrapping
# pd.set_option('display.max_colwidth', None)  # Show full column content

pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.width')
pd.reset_option('display.max_colwidth')
# -------------------------------------------------------------------------
#   The ID of each event can be found in HLTV in either of the links below
#   For example: 
#   https://www.hltv.org/events/7909/blast-bounty-2025-season-1-finals
#   https://www.hltv.org/results?event=7909
# -------------------------------------------------------------------------

id_event = [7909,  # Blast Bounty 2025 Season 1 Finals
            7903, # Blast Bounty 2025 Season 1 
            7524, # Perfect World Shanghai Major 2024
            7557  # BLAST Premier World Final 2024
            ]

root = os.getcwd() # Get the root directory

# %% [markdown]
# ### **ACTUAL SCRAPING**

# %%
# Gets the URLs from all the matches in the event and other info into a pandas dataframe
tournaments_df = get_matches_url(*id_event)

# Get an ID for each match used in a url
tournaments_df = get_match_ids(tournaments_df)

# Makes a get request to fetch the direct links to download the demos
tournaments_df = get_request(tournaments_df)
                           
# Makes the request to fetch the direct link to download the demos
tournaments_df = download_files(tournaments_df)

unrar(tournaments_df)

run_csda_on_demos(tournaments_df)

match_data = merge_csv_files(tournaments_df)
# Out:
# ---------------------------------------------
#        MATCHUPS CAN BE Bo1, Bo3 or Bo5
# ---------------------------------------------
#
# Event: BLAST Bounty 2025 Season 1 Finals
# Number of matchups: 7
#
# Event: BLAST Bounty 2025 Season 1
# Number of matchups: 24
#
# Event: Perfect World Shanghai Major 2024
# Number of matchups: 40
#
# Event: BLAST Premier World Final 2024
# Number of matchups: 13
#
#
# Total number of matchups: 84
# ---------------------------------------------
# Fetching Match IDs : 100%|███████████████████████████████████████████████████████████| 84/84 [21:18]
# Downloading .rar   : 100%|███████████████████████████████████████████████████████████| 84/84 [12:29]
# Exctracting .rar   : 100%|███████████████████████████████████████████████████████████| 84/84 [08:07]
# ---------------------------------------------
#
# Number of games: 57
# Processing BLAST Bounty 2025 Season 1: 100%|█████████████████████████████████████████| 57/57 [10:39]
# ---------------------------------------------
#
# Number of games: 18
# Processing BLAST Bounty 2025 Season 1 Finals: 100%|██████████████████████████████████| 18/18 [03:18]
# ---------------------------------------------
#
# Number of games: 32
# Processing BLAST Premier World Final 2024: 100%|█████████████████████████████████████| 32/32 [06:29]
# ---------------------------------------------
#
# Number of games: 72
# Processing Perfect World Shanghai Major 2024: 100%|██████████████████████████████████| 72/72 [12:28]

# %%
# Access individual DataFrames
matches_df = match_data['_match']
teams_df = match_data['_teams']
kills_df = match_data['_kills']
players_df = match_data['_players']
players_economy_df = match_data['_players_economy']
clutches_df = match_data['_clutches']

# %%
# Display DataFrames
print("\nMatches:")
display(matches_df)

print("\nTeams:")
display(teams_df)

print("\nKills:")
display(kills_df)

print("\nPlayers:")
display(players_df)

print("\nPlayers Economy:")
display(players_economy_df)

print("\nClutches:")
display(clutches_df)
# Out:
# Matches:
#              checksum                      date         map  \
# 0    1229e6b33a7c388f 2025-01-14 13:32:46-03:00  de_ancient
# 1    409bde782d701247 2025-01-14 13:32:46-03:00    de_dust2
# 2    c92c0fe937a29b0e 2025-01-14 16:55:20-03:00   de_anubis
# 3    e404f30b9dc3e185 2025-01-18 17:43:13-03:00  de_inferno
# 4    339f817fc0609ea4 2025-01-18 18:26:10-03:00  de_ancient
# ..                ...                       ...         ...
# 174  ef5428fc5dae1544 2024-12-13 08:06:42-03:00   de_anubis
# 175  78b35a05e1f27c73 2024-12-05 04:17:30-03:00   de_mirage
# 176  2740f54047c83411 2024-12-05 12:51:46-03:00   de_mirage
# 177  b3f709fcb800bb07 2024-12-06 00:57:34-03:00   de_mirage
# 178   294467d4121747c 2024-12-06 01:58:40-03:00   de_anubis
#
#                             tournament
# 0           BLAST Bounty 2025 Season 1
# 1           BLAST Bounty 2025 Season 1
# 2           BLAST Bounty 2025 Season 1
# 3           BLAST Bounty 2025 Season 1
# 4           BLAST Bounty 2025 Season 1
# ..                                 ...
# 174  Perfect World Shanghai Major 2024
# 175  Perfect World Shanghai Major 2024
# 176  Perfect World Shanghai Major 2024
# 177  Perfect World Shanghai Major 2024
# 178  Perfect World Shanghai Major 2024
#
# [179 rows x 4 columns]
# Teams:
#             name    team    match_checksum                         tournament
# 0          3DMAX  Team A  1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# 1         HEROIC  Team B  1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# 2         Team A  Team A  409bde782d701247         BLAST Bounty 2025 Season 1
# 3         Team B  Team B  409bde782d701247         BLAST Bounty 2025 Season 1
# 4         HEROIC  Team A  c92c0fe937a29b0e         BLAST Bounty 2025 Season 1
# ..           ...     ...               ...                                ...
# 353  GamerLegion  Team B  2740f54047c83411  Perfect World Shanghai Major 2024
# 354         MIBR  Team A  b3f709fcb800bb07  Perfect World Shanghai Major 2024
# 355     Vitality  Team B  b3f709fcb800bb07  Perfect World Shanghai Major 2024
# 356         MIBR  Team A   294467d4121747c  Perfect World Shanghai Major 2024
# 357     Vitality  Team B   294467d4121747c  Perfect World Shanghai Major 2024
#
# [358 rows x 4 columns]
# Kills:
#       killer_name     killer_steamid killer_team_name victim_name  \
# 0         Graviti  76561198179538505            3DMAX     Graviti
# 1           Djoko  76561198047876970            3DMAX    yxngstxr
# 2          xfl0ud  76561198178209109           HEROIC    Ex3rcice
# 3           Djoko  76561198047876970            3DMAX      xfl0ud
# 4        SunPayus  76561198309839541           HEROIC        Maka
# ...           ...                ...              ...         ...
# 26358      saffee  76561197985565685             MIBR       Spinx
# 26359       ZywOo  76561198113666193         Vitality      saffee
# 26360      flameZ  76561197978835160         Vitality      insani
# 26361        exit  76561198010496342             MIBR      flameZ
# 26362       mezii  76561197973140692         Vitality        exit
#
#           victim_steamid  victim_side victim_team_name weapon_name  headshot  \
# 0      76561198179538505            3            3DMAX       World         0
# 1      76561199137143905            2           HEROIC       USP-S         1
# 2      76561198168198200            3            3DMAX    Glock-18         1
# 3      76561198178209109            2           HEROIC       USP-S         1
# 4      76561198045739761            3            3DMAX    Glock-18         0
# ...                  ...          ...              ...         ...       ...
# 26358  76561198063336407            3         Vitality       AK-47         1
# 26359  76561197985565685            2             MIBR       AK-47         1
# 26360  76561198061423730            2             MIBR        M4A4         0
# 26361  76561197978835160            3         Vitality       AK-47         0
# 26362  76561198010496342            2             MIBR       AK-47         0
#
#        killer_controlling_bot  is_trade_kill    match_checksum  \
# 0                           0              0  1229e6b33a7c388f
# 1                           0              0  1229e6b33a7c388f
# 2                           0              0  1229e6b33a7c388f
# 3                           0              1  1229e6b33a7c388f
# 4                           0              0  1229e6b33a7c388f
# ...                       ...            ...               ...
# 26358                       0              0   294467d4121747c
# 26359                       0              0   294467d4121747c
# 26360                       0              0   294467d4121747c
# 26361                       0              1   294467d4121747c
# 26362                       0              0   294467d4121747c
#
#                               tournament
# 0             BLAST Bounty 2025 Season 1
# 1             BLAST Bounty 2025 Season 1
# 2             BLAST Bounty 2025 Season 1
# 3             BLAST Bounty 2025 Season 1
# 4             BLAST Bounty 2025 Season 1
# ...                                  ...
# 26358  Perfect World Shanghai Major 2024
# 26359  Perfect World Shanghai Major 2024
# 26360  Perfect World Shanghai Major 2024
# 26361  Perfect World Shanghai Major 2024
# 26362  Perfect World Shanghai Major 2024
#
# [26363 rows x 13 columns]
# Players:
#           name            steamid team_name  kills  assists  deaths  \
# 0     SunPayus  76561198309839541    HEROIC     10       12      21
# 1          LNZ  76561198104626893    HEROIC     24        3      21
# 2         tN1R  76561198872013168    HEROIC     33        5      17
# 3     yxngstxr  76561199137143905    HEROIC     27        8      22
# 4     Ex3rcice  76561198168198200     3DMAX     26        1      20
# ...        ...                ...       ...    ...      ...     ...
# 1785    flameZ  76561197978835160  Vitality     11        4      13
# 1786      drop  76561198388056582      MIBR      8        3      14
# 1787     ZywOo  76561198113666193  Vitality     14        5       9
# 1788   Lucaozy  76561198157388473      MIBR      6        4      10
# 1789      exit  76561198010496342      MIBR     11        3      13
#
#       headshots  hs_%       k/d       kast  ...  first_death  trade_kill  \
# 0             4    40  0.476190  80.000000  ...            1           1
# 1            10    41  1.142857  76.666664  ...            5           7
# 2            19    57  1.941176  80.000000  ...            2           5
# 3            13    48  1.227273  70.000000  ...            4           9
# 4            13    50  1.300000  76.666664  ...            2           4
# ...         ...   ...       ...        ...  ...          ...         ...
# 1785          4    36  0.846154  94.444443  ...            2           0
# 1786          3    37  0.571429  61.111111  ...            3           3
# 1787          9    64  1.555556  88.888893  ...            3           3
# 1788          2    33  0.600000  72.222221  ...            1           1
# 1789          2    18  0.846154  83.333328  ...            1           6
#
#       trade_death  1k  2k  3k  4k  5k    match_checksum  \
# 0              10   8   1   0   0   0  1229e6b33a7c388f
# 1               5   9   3   3   0   0  1229e6b33a7c388f
# 2               4  10   5   3   1   0  1229e6b33a7c388f
# 3               1   5   8   2   0   0  1229e6b33a7c388f
# 4               5   9   5   1   1   0  1229e6b33a7c388f
# ...           ...  ..  ..  ..  ..  ..               ...
# 1785            7   8   0   1   0   0   294467d4121747c
# 1786            3   2   3   0   0   0   294467d4121747c
# 1787            0   8   3   0   0   0   294467d4121747c
# 1788            3   4   1   0   0   0   294467d4121747c
# 1789            1   7   2   0   0   0   294467d4121747c
#
#                              tournament
# 0            BLAST Bounty 2025 Season 1
# 1            BLAST Bounty 2025 Season 1
# 2            BLAST Bounty 2025 Season 1
# 3            BLAST Bounty 2025 Season 1
# 4            BLAST Bounty 2025 Season 1
# ...                                 ...
# 1785  Perfect World Shanghai Major 2024
# 1786  Perfect World Shanghai Major 2024
# 1787  Perfect World Shanghai Major 2024
# 1788  Perfect World Shanghai Major 2024
# 1789  Perfect World Shanghai Major 2024
#
# [1790 rows x 28 columns]
# Players Economy:
#                  steamid      name        player_side  equipment_value  \
# 0      76561198104626893       LNZ          Terrorist              900
# 1      76561198872013168      tN1R          Terrorist             1050
# 2      76561198047876970     Djoko  Counter Terrorist              850
# 3      76561198179538505   Graviti  Counter Terrorist              700
# 4      76561198309839541  SunPayus          Terrorist             1050
# ...                  ...       ...                ...              ...
# 39323  76561197978835160    flameZ  Counter Terrorist             5100
# 39324  76561198063336407     Spinx  Counter Terrorist             5600
# 39325  76561198113666193     ZywOo  Counter Terrorist             5400
# 39326  76561198157388473   Lucaozy          Terrorist             4600
# 39327  76561198010496342      exit          Terrorist             3900
#
#          type    match_checksum                         tournament
# 0      pistol  1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# 1      pistol  1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# 2      pistol  1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# 3      pistol  1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# 4      pistol  1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# ...       ...               ...                                ...
# 39323    full   294467d4121747c  Perfect World Shanghai Major 2024
# 39324    full   294467d4121747c  Perfect World Shanghai Major 2024
# 39325    full   294467d4121747c  Perfect World Shanghai Major 2024
# 39326    full   294467d4121747c  Perfect World Shanghai Major 2024
# 39327    semi   294467d4121747c  Perfect World Shanghai Major 2024
#
# [39328 rows x 7 columns]
# Clutches:
#       won            steamid      name  survived  kill_count  \
# 0       0  76561198179538505   Graviti         0           1
# 1       1  76561198872013168      tN1R         1           1
# 2       0  76561198031890115     Lucky         0           1
# 3       1  76561198104626893       LNZ         1           1
# 4       1  76561199137143905  yxngstxr         1           1
# ...   ...                ...       ...       ...         ...
# 3991    0  76561197989744167      apEX         1           0
# 3992    0  76561198113666193     ZywOo         0           1
# 3993    0  76561198010496342      exit         0           2
# 3994    0  76561198010496342      exit         0           0
# 3995    0  76561198010496342      exit         0           1
#
#         match_checksum                         tournament
# 0     1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# 1     1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# 2     1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# 3     1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# 4     1229e6b33a7c388f         BLAST Bounty 2025 Season 1
# ...                ...                                ...
# 3991   294467d4121747c  Perfect World Shanghai Major 2024
# 3992   294467d4121747c  Perfect World Shanghai Major 2024
# 3993   294467d4121747c  Perfect World Shanghai Major 2024
# 3994   294467d4121747c  Perfect World Shanghai Major 2024
# 3995   294467d4121747c  Perfect World Shanghai Major 2024
#
# [3996 rows x 7 columns]

# %%
# Just exporting the tables in markdown format
output_dir = "github_tables"
os.makedirs(output_dir, exist_ok=True)

    
output_file = os.path.join(output_dir, "all_tables.txt")
with open(output_file, 'w') as f:
    for name, df in match_data.items():
        # Write table name as header
        f.write(f"\n{name.strip('_')} Table:\n")
        # Write header row
        f.write('| ' + ' | '.join(df.columns) + ' |\n')
        # Write separator row
        f.write('|' + '|'.join(['---' for _ in df.columns]) + '|\n')
        # Write first data row only
        first_row = df.iloc[0].astype(str)
        f.write('| ' + ' | '.join(first_row) + ' |\n')
        f.write('\n') # Add blank line between tables
    print(f"Saved all tables to {output_file}")
# Out:
# Saved all tables to github_tables\all_tables.txt

# %%
# Export tables to csv
for name, df in match_data.items():
    output_file = os.path.join(output_dir, f"{name.strip('_')}.csv")
    df.to_csv(output_file, index=False)
    print(f"Saved {output_file}")
# Out:
# Saved github_tables\clutches.csv
# Saved github_tables\kills.csv
# Saved github_tables\match.csv
# Saved github_tables\players.csv
# Saved github_tables\players_economy.csv
# Saved github_tables\teams.csv
