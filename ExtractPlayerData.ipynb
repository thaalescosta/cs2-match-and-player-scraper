# %% [markdown]
# ### **SCRAPING THE PLAYERS/TEAMS INFO FOR THE TOP X HLTV TEAMS** ##

# %%
from ExtractPlayerData._functions.get_team_data import get_team_data
from ExtractPlayerData._functions.get_player_photos import get_player_photos, pd
from ExtractPlayerData._functions.download_photos import download_photos
import os

# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Disable line wrapping
# pd.set_option('display.max_colwidth', None)  # Show full column content

pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns') 
pd.reset_option('display.width')
pd.reset_option('display.max_colwidth')


topN = 50 ## GET THE PLAYERS/TEAMS INFO FOR THE TOP X HLTV TEAMS ## 

url = "https://www.hltv.org/ranking/teams/2025/february/10"

pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Disable line wrapping
pd.set_option('display.max_colwidth', None)  # Show full column content

players_data = get_team_data(url, topN)

players_data = get_player_photos(players_data)

players_data = download_photos(players_data)
# Out:
# Fetching player photo URLs:  99%|█████████████████████████████████████████████████▍| 247/250 [10:30]
# All players who had their photos on HLTV have been downloaded

# %%
photo_players_path = os.path.join(os.getcwd(), "ExtractPlayerData", "photo_players")
print(f'\nThe flag and players PNGs are saved in:\n{photo_players_path}')
# Out:
# The flag and players PNGs are saved in:
# c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players

# %%
display(players_data)
# Out:
#        team_name                                   team_page  \
# 0         Spirit       https://www.hltv.org/team/7020/spirit
# 1         Spirit       https://www.hltv.org/team/7020/spirit
# 2         Spirit       https://www.hltv.org/team/7020/spirit
# 3         Spirit       https://www.hltv.org/team/7020/spirit
# 4         Spirit       https://www.hltv.org/team/7020/spirit
# ..           ...                                         ...
# 245  Lynn Vision  https://www.hltv.org/team/8840/lynn-vision
# 246  Lynn Vision  https://www.hltv.org/team/8840/lynn-vision
# 247  Lynn Vision  https://www.hltv.org/team/8840/lynn-vision
# 248  Lynn Vision  https://www.hltv.org/team/8840/lynn-vision
# 249  Lynn Vision  https://www.hltv.org/team/8840/lynn-vision
#
#                      player_name player_country     player_nick  \
# 0    Leonid 'chopper' Vishnyakov         Russia         chopper
# 1         Dmitry 'sh1ro' Sokolov         Russia           sh1ro
# 2        Boris 'magixx' Vorobiev         Russia          magixx
# 3    Myroslav 'zont1x' Plakhotia        Ukraine          zont1x
# 4       Danil 'donk' Kryshkovets         Russia            donk
# ..                           ...            ...             ...
# 245               missing_player            n/a  missing_player
# 246          Zhe 'Westmelon' Niu          China       Westmelon
# 247            Sike 'z4kr' Zhang          China            z4kr
# 248            Lizhi 'Starry' Ye          China          Starry
# 249      Junjie 'EmiliaQAQ' Tang          China       EmiliaQAQ
#
#                                  player_hltv_url  \
# 0       https://www.hltv.org/player/7716/chopper
# 1        https://www.hltv.org/player/16920/sh1ro
# 2       https://www.hltv.org/player/18317/magixx
# 3       https://www.hltv.org/player/20423/zont1x
# 4         https://www.hltv.org/player/21167/donk
# ..                                           ...
# 245                                       no url
# 246  https://www.hltv.org/player/16551/westmelon
# 247       https://www.hltv.org/player/18744/z4kr
# 248     https://www.hltv.org/player/20254/starry
# 249  https://www.hltv.org/player/22922/emiliaqaq
#
#                                                                                                                      photo_player  \
# 0    https://img-cdn.hltv.org/playerbodyshot/rl_4NtItqpjwLHZL12oMNb.png?ixlib=java-2.1.0&w=400&s=e017b74a48aab673759886475cdfac23
# 1    https://img-cdn.hltv.org/playerbodyshot/-SSnjUN7O5HVENMxG2yReD.png?ixlib=java-2.1.0&w=400&s=3d3dd660e3f0d5287910e6f7d3bbe335
# 2    https://img-cdn.hltv.org/playerbodyshot/KL_btdQvRC_EPR0c0HdMuZ.png?ixlib=java-2.1.0&w=400&s=c019ad746ce84b793e7ca7d2bcadf57a
# 3    https://img-cdn.hltv.org/playerbodyshot/9W11pewP-V5WZM0KR3GH4v.png?ixlib=java-2.1.0&w=400&s=32961c4bb7501a4fcb91d64f66cf204d
# 4    https://img-cdn.hltv.org/playerbodyshot/snAlUrdIT8ifI4qzNHfLow.png?ixlib=java-2.1.0&w=400&s=e4106a3742a9cd38c16c10e5a642e9f6
# ..                                                                                                                            ...
# 245                                                                  https://www.hltv.org/img/static/player/player_silhouette.png
# 246  https://img-cdn.hltv.org/playerbodyshot/uXUgjI6jUYnxoqgAVaXZE9.png?ixlib=java-2.1.0&w=400&s=ff16f491a2380232f135107d17dd82eb
# 247  https://img-cdn.hltv.org/playerbodyshot/-f1fkI2t5rG3Yx5_i8UPU_.png?ixlib=java-2.1.0&w=400&s=f501bf57c0062fba2c3b37495dfe10ee
# 248  https://img-cdn.hltv.org/playerbodyshot/4tO_SQL8I7pr4dKJM34duT.png?ixlib=java-2.1.0&w=400&s=60f8289842c4a6e3bec8a53c721c40e1
# 249  https://img-cdn.hltv.org/playerbodyshot/38FFT8AHDK6pOKDqDlxy2s.png?ixlib=java-2.1.0&w=400&s=de157513e5b53fbcf66830e217fa6f49
#
#                                             player_flag  \
# 0    https://www.hltv.org/img/static/flags/30x20/RU.gif
# 1    https://www.hltv.org/img/static/flags/30x20/RU.gif
# 2    https://www.hltv.org/img/static/flags/30x20/RU.gif
# 3    https://www.hltv.org/img/static/flags/30x20/UA.gif
# 4    https://www.hltv.org/img/static/flags/30x20/RU.gif
# ..                                                  ...
# 245                                                 NaN
# 246  https://www.hltv.org/img/static/flags/30x20/CN.gif
# 247  https://www.hltv.org/img/static/flags/30x20/CN.gif
# 248  https://www.hltv.org/img/static/flags/30x20/CN.gif
# 249  https://www.hltv.org/img/static/flags/30x20/CN.gif
#
#                                                                              photo_player_path  \
# 0           c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\spirit-chopper.png
# 1             c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\spirit-sh1ro.png
# 2            c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\spirit-magixx.png
# 3            c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\spirit-zont1x.png
# 4              c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\spirit-donk.png
# ..                                                                                         ...
# 245                                                                                        NaN
# 246  c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\lynn-vision-Westmelon.png
# 247       c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\lynn-vision-z4kr.png
# 248     c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\lynn-vision-Starry.png
# 249  c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\lynn-vision-EmiliaQAQ.png
#
#                                                                        player_flag_path
# 0     c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\russia.png
# 1     c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\russia.png
# 2     c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\russia.png
# 3    c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\ukraine.png
# 4     c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\russia.png
# ..                                                                                  ...
# 245                                                                                 NaN
# 246    c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\china.png
# 247    c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\china.png
# 248    c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\china.png
# 249    c:\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\china.png
#
# [250 rows x 10 columns]
