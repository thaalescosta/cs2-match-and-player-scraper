# %% [markdown]
# ### **SCRAPING THE PLAYERS/TEAMS INFO FOR THE TOP X HLTV TEAMS** ##

# %%
from ExtractPlayerData._functions.get_team_data import get_team_data
from ExtractPlayerData._functions.get_player_photos import get_player_photos
from ExtractPlayerData._functions.download_photos import download_photos
import pandas as pd
import os

# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Disable line wrapping
# pd.set_option('display.max_colwidth', None)  # Show full column content

pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns') 
pd.reset_option('display.width')
pd.reset_option('display.max_colwidth')


topN = 50 ## GET THE PLAYERS/TEAMS INFO FOR THE TOP X HLTV TEAMS ## 

url = "https://www.hltv.org/ranking/teams/2025/march/3"

pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Disable line wrapping
pd.set_option('display.max_colwidth', None)  # Show full column content

players_data = get_team_data(url, topN)

players_data = get_player_photos(players_data)

players_data = download_photos(players_data)
# Out:
# Fetching player photo URLs:  99%|█████████████████████████████████████████████████▌| 248/250 [10:13]
# The progress bar not reaching 100% just means that some players don't have their photo on HLTV

# %%
players_data.to_csv(os.path.join("ExtractPlayerData", "players_data.csv"), index=False, encoding='utf-8')

photo_players_path = os.path.join(os.getcwd(), "ExtractPlayerData", "photo_players")
print(f'\nThe flag and players PNGs are saved in:\n{photo_players_path}')
players_data.head()
# Out:
# The flag and players PNGs are saved in:
# c:\Projects\cs2-match-and-player-scraper\ExtractPlayerData\photo_players
#   team_name                              team_page  \
# 0    Spirit  https://www.hltv.org/team/7020/spirit
# 1    Spirit  https://www.hltv.org/team/7020/spirit
# 2    Spirit  https://www.hltv.org/team/7020/spirit
# 3    Spirit  https://www.hltv.org/team/7020/spirit
# 4    Spirit  https://www.hltv.org/team/7020/spirit
#
#                    player_name player_country player_nick  \
# 0  Leonid 'chopper' Vishnyakov         Russia     chopper
# 1       Dmitry 'sh1ro' Sokolov         Russia       sh1ro
# 2      Boris 'magixx' Vorobiev         Russia      magixx
# 3  Myroslav 'zont1x' Plakhotia        Ukraine      zont1x
# 4     Danil 'donk' Kryshkovets         Russia        donk
#
#                             player_hltv_url  \
# 0  https://www.hltv.org/player/7716/chopper
# 1   https://www.hltv.org/player/16920/sh1ro
# 2  https://www.hltv.org/player/18317/magixx
# 3  https://www.hltv.org/player/20423/zont1x
# 4    https://www.hltv.org/player/21167/donk
#
#                                                                                                                    photo_player  \
# 0  https://img-cdn.hltv.org/playerbodyshot/rl_4NtItqpjwLHZL12oMNb.png?ixlib=java-2.1.0&w=400&s=e017b74a48aab673759886475cdfac23
# 1  https://img-cdn.hltv.org/playerbodyshot/-SSnjUN7O5HVENMxG2yReD.png?ixlib=java-2.1.0&w=400&s=3d3dd660e3f0d5287910e6f7d3bbe335
# 2  https://img-cdn.hltv.org/playerbodyshot/KL_btdQvRC_EPR0c0HdMuZ.png?ixlib=java-2.1.0&w=400&s=c019ad746ce84b793e7ca7d2bcadf57a
# 3  https://img-cdn.hltv.org/playerbodyshot/9W11pewP-V5WZM0KR3GH4v.png?ixlib=java-2.1.0&w=400&s=32961c4bb7501a4fcb91d64f66cf204d
# 4  https://img-cdn.hltv.org/playerbodyshot/snAlUrdIT8ifI4qzNHfLow.png?ixlib=java-2.1.0&w=400&s=e4106a3742a9cd38c16c10e5a642e9f6
#
#                                           player_flag  \
# 0  https://www.hltv.org/img/static/flags/30x20/RU.gif
# 1  https://www.hltv.org/img/static/flags/30x20/RU.gif
# 2  https://www.hltv.org/img/static/flags/30x20/RU.gif
# 3  https://www.hltv.org/img/static/flags/30x20/UA.gif
# 4  https://www.hltv.org/img/static/flags/30x20/RU.gif
#
#                                                                              photo_player_path  \
# 0  c:\Projects\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\spirit-chopper.png
# 1    c:\Projects\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\spirit-sh1ro.png
# 2   c:\Projects\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\spirit-magixx.png
# 3   c:\Projects\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\spirit-zont1x.png
# 4     c:\Projects\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\spirit-donk.png
#
#                                                                               player_flag_path
# 0   c:\Projects\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\russia.png
# 1   c:\Projects\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\russia.png
# 2   c:\Projects\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\russia.png
# 3  c:\Projects\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\ukraine.png
# 4   c:\Projects\cs2-match-and-player-scraper\ExtractPlayerData\photo_players\_flags\russia.png

# %%
# %pip install mysql.connector
# Out:
# Collecting mysql.connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ------- -------------------------------- 2.1/11.9 MB 25.8 MB/s eta 0:00:01
#      --------------------------------------- 11.9/11.9 MB 38.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: mysql.connector
#   Building wheel for mysql.connector (pyproject.toml): started
#   Building wheel for mysql.connector (pyproject.toml): finished with status 'done'
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp313-cp313-win_amd64.whl size=248023 sha256=ec94afc7b7c98220a7b35755370e53a70486ab592599f166cb9692e2035068f7
#   Stored in directory: c:\users\thales\appdata\local\pip\cache\wheels\4e\c1\23\9423c444a75266a05275c80ebf5c6efe2368388e976b690a0f
# Successfully built mysql.connector
# Installing collected packages: mysql.connector
# Successfully installed mysql.connector-2.2.9

# %%
# import mysql.connector
# from mysql.connector import Error

# # MySQL database connection parameters
# db_params = {
#     'host': 'localhost',
#     'password': '1234',
# }

# try:
#     # Connect to MySQL server
#     connection = mysql.connector.connect(**db_params)
#     cursor = connection.cursor()

#     # Create database if it doesn't exist
#     cursor.execute("CREATE DATABASE IF NOT EXISTS dbCounterStrike2")
#     cursor.execute("USE dbCounterStrike2")

#     # Create players table
#     create_table_query = """
#     CREATE TABLE IF NOT EXISTS players (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     team_name VARCHAR(255),
#     team_page VARCHAR(255),
#     player_name VARCHAR(255),
#     player_country VARCHAR(255),
#     player_nick VARCHAR(255),
#     photo_player VARCHAR(255),
#     player_flag VARCHAR(255),
#     photo_player_path VARCHAR(255),
#     player_flag_path VARCHAR(255)
#     )
#     """
#     cursor.execute(create_table_query)

# except Error as e:
#     print(f"Error connecting to MySQL: {e}")
# Out:
# Error connecting to MySQL: Authentication plugin 'caching_sha2_password' is not supported

# %%
# # Insert data into table
# insert_query = """
# INSERT INTO players (
# team_name, team_page, player_name, player_country,
# player_nick, photo_player, player_flag, photo_player_path,
# player_flag_path
# ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
# """

# # Convert DataFrame to list of tuples for insertion
# values = players_data.values.tolist()
# cursor.executemany(insert_query, values)

# # Commit changes
# connection.commit()
# print("Data successfully inserted into MySQL database")

# if connection.is_connected():
#     cursor.close()
#     connection.close()
#     print("MySQL connection closed")
